# %% [markdown]
# <a href="https://colab.research.google.com/github/yegisafari/DenseNet/blob/main/assignmnet4_yeganehsafari_deeplearning_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Deep Learning
# #Assignmnet 4
# #Yeganeh Safari

# %% [markdown]
# 1. Read the original DenseNet paper, which can be found here: https://arxiv.org/pdf/
# 1608.06993.pdf.
# 2. There are a few custom building blocks that need to be implemented for a DenseNet
# model: The composition function, the actual DenseNet block, and the transition block.
# These can be defined quite straighforwardly using Keras’ functional API.
# 3. As DenseNets increase the number of feature maps over each DenseNet block, to make
# the model more compact, also a compression factor can be implemented for the transition
# block. Here, use a compression factor of θ = 0.5.
# 4. Note that in the DenseNet paper, a second version is proposed that also includes Bottle-
# neck layers. You can experiment with those as well, but they may not be needed for the
# relatively small CIFAR-10 Dataset.
# 5. As actual architecture, use a network that uses a total of 3 DenseNet blocks, with a
# growth rate of k = 12. Process the input images as described in the paper.
# 6. For the classifier part of the network (i.e. the part after the DenseNet blocks) use global
# averaging pooling, followed by the dense output layer (as in GoogLeNet).
# 7. There are two sets of experiments reported in the paper for CIFAR-10. One using data
# augmentation (as we have seen in class) but no dropout, and one using dropout but no
# data augmentation. Try out both, using a dropout rate of 20%.
# 8. Evaluate all your models on the test dataset. Which version gives the most accurate
# results? Does your DenseNet model beat the other models we have seen in class?

# %%
from tensorflow.keras.layers import BatchNormalization, Activation, Conv2D, concatenate
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, concatenate
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Dense, Dropout, Flatten, Input, concatenate, BatchNormalization, Activation, GlobalAveragePooling2D
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import AveragePooling2D
import tensorflow as tf
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, AveragePooling2D, Concatenate, GlobalAveragePooling2D, Dense
import tensorflow.keras.backend as K
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision.models import densenet121

# %%
cifar_10 = tf.keras.datasets.cifar10

# %%
(X_train, Y_train), (X_test, Y_test) = cifar_10.load_data()

# %%
x_train = x_train.astype('float32')
x_train = x_train/255.0

x_test = x_test.astype('float32')
x_test = x_test/255.0

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
y_test.shape
# Out:
# (10000, 1)

# %%
def composition_function(inputs, filter, kernel_size, dropout=0.0):
   x = tf.keras.layers.BatchNormalization()(inputs)
   x = tf.keras.layers.Activation('relu')(x)
   x = tf.keras.layers.Conv2D(filter, kernel_size, padding='same')(x)
   outputs = tf.keras.layers.Dropout(dropout)(x)
   return outputs

# %%
# DenseNet block
def densenet_block(inputs, layers, filters, dropout=0.0, bottleneck=False):
  for _ in range(layers):
    if bottleneck:
      x = composition_function(inputs, 4*filters, (1,1), dropout=dropout)
    else:
      x = inputs
    x = composition_function(x, filters, (3,3), dropout=dropout)
    inputs = tf.keras.layers.Concatenate(axis=-1)([x, inputs])
  return inputs
def densenet_block(inputs, layers, filters, dropout=0.0, bottleneck=False):
  for _ in range(layers):
    if bottleneck:
      x = composition_function(inputs, 4*filters, (1,1), dropout=dropout)
    else:
      x = inputs
    x = composition_function(x, filters, (3,3), dropout=dropout)
    inputs = tf.keras.layers.Concatenate(axis=-1)([x, inputs])
  return inputs

# %%
# Compression fcator alpha = 0.5
def transition_block(inputs, compression=0.5, dropout=0.00):
  filters = tf.keras.backend.int_shape(inputs)[-1]
  filters = int(filters * compression)
  x = composition_function(inputs, filters, (1, 1), dropout=dropout)
  outputs = tf.keras.layers.AveragePooling2D(pool_size=(2,2), strides=(2,2), padding='same')(x)
  return outputs

# %%
#Data augmentation
input_shape = (32, 32, 3)
n_classes = 10
blocks = (6, 12, 24)
growth_rate = 12
compression_rate = 0.5
dropout_rate = 0.0
bottleneck = True

# %%
inputs = tf.keras.Input(shape=input_shape)
x = tf.keras.layers.RandomFlip('horizontal')(inputs)
x = tf.keras.layers.RandomRotation(0.2)(x)

# %%
# Convolution layer
x = tf.keras.layers.Conv2D(2*growth_rate, (5, 5), strides=(2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Activation('relu')(x)
x = tf.keras.layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)

# %%
# Dense net
for i, num in enumerate(blocks):
    x = densenet_block(x, num, growth_rate, dropout=dropout_rate, bottleneck = bottleneck)
    if i != len(blocks) - 1:
        x = transition_block(x, compression=compression_rate, dropout=dropout_rate)

x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Activation('relu')(x)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(n_classes, activation='softmax')(x)

aug_model = tf.keras.Model(inputs=inputs, outputs=x)

aug_model.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_13 (InputLayer)       [(None, 32, 32, 3)]          0         []
#
#  random_flip (RandomFlip)    (None, 32, 32, 3)            0         ['input_13[0][0]']
#
#  random_rotation (RandomRot  (None, 32, 32, 3)            0         ['random_flip[0][0]']
#  ation)
#
#  conv2d_130 (Conv2D)         (None, 16, 16, 24)           1824      ['random_rotation[0][0]']
#
#  batch_normalization_121 (B  (None, 16, 16, 24)           96        ['conv2d_130[0][0]']
#  atchNormalization)
#
#  activation_121 (Activation  (None, 16, 16, 24)           0         ['batch_normalization_121[0][0
#  )                                                                  ]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 8, 8, 24)             0         ['activation_121[0][0]']
#  g2D)
#
#  conv2d_131 (Conv2D)         (None, 4, 4, 24)             14424     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_122 (B  (None, 4, 4, 24)             96        ['conv2d_131[0][0]']
#  atchNormalization)
#
#  activation_122 (Activation  (None, 4, 4, 24)             0         ['batch_normalization_122[0][0
#  )                                                                  ]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 2, 2, 24)             0         ['activation_122[0][0]']
#  g2D)
#
#  batch_normalization_123 (B  (None, 2, 2, 24)             96        ['max_pooling2d_3[0][0]']
#  atchNormalization)
#
#  activation_123 (Activation  (None, 2, 2, 24)             0         ['batch_normalization_123[0][0
#  )                                                                  ]']
#
#  conv2d_132 (Conv2D)         (None, 2, 2, 48)             1200      ['activation_123[0][0]']
#
#  dropout_2 (Dropout)         (None, 2, 2, 48)             0         ['conv2d_132[0][0]']
#
#  batch_normalization_124 (B  (None, 2, 2, 48)             192       ['dropout_2[0][0]']
#  atchNormalization)
#
#  activation_124 (Activation  (None, 2, 2, 48)             0         ['batch_normalization_124[0][0
#  )                                                                  ]']
#
#  conv2d_133 (Conv2D)         (None, 2, 2, 12)             5196      ['activation_124[0][0]']
#
#  dropout_3 (Dropout)         (None, 2, 2, 12)             0         ['conv2d_133[0][0]']
#
#  concatenate_86 (Concatenat  (None, 2, 2, 36)             0         ['dropout_3[0][0]',
#  e)                                                                  'max_pooling2d_3[0][0]']
#
#  batch_normalization_125 (B  (None, 2, 2, 36)             144       ['concatenate_86[0][0]']
#  atchNormalization)
#
#  activation_125 (Activation  (None, 2, 2, 36)             0         ['batch_normalization_125[0][0
#  )                                                                  ]']
#
#  conv2d_134 (Conv2D)         (None, 2, 2, 48)             1776      ['activation_125[0][0]']
#
#  dropout_4 (Dropout)         (None, 2, 2, 48)             0         ['conv2d_134[0][0]']
#
#  batch_normalization_126 (B  (None, 2, 2, 48)             192       ['dropout_4[0][0]']
#  atchNormalization)
#
#  activation_126 (Activation  (None, 2, 2, 48)             0         ['batch_normalization_126[0][0
#  )                                                                  ]']
#
#  conv2d_135 (Conv2D)         (None, 2, 2, 12)             5196      ['activation_126[0][0]']
#
#  dropout_5 (Dropout)         (None, 2, 2, 12)             0         ['conv2d_135[0][0]']
#
#  concatenate_87 (Concatenat  (None, 2, 2, 48)             0         ['dropout_5[0][0]',
#  e)                                                                  'concatenate_86[0][0]']
#
#  batch_normalization_127 (B  (None, 2, 2, 48)             192       ['concatenate_87[0][0]']
#  atchNormalization)
#
#  activation_127 (Activation  (None, 2, 2, 48)             0         ['batch_normalization_127[0][0
#  )                                                                  ]']
#
#  conv2d_136 (Conv2D)         (None, 2, 2, 48)             2352      ['activation_127[0][0]']
#
#  dropout_6 (Dropout)         (None, 2, 2, 48)             0         ['conv2d_136[0][0]']
#
#  batch_normalization_128 (B  (None, 2, 2, 48)             192       ['dropout_6[0][0]']
#  atchNormalization)
#
#  activation_128 (Activation  (None, 2, 2, 48)             0         ['batch_normalization_128[0][0
#  )                                                                  ]']
#
#  conv2d_137 (Conv2D)         (None, 2, 2, 12)             5196      ['activation_128[0][0]']
#
#  dropout_7 (Dropout)         (None, 2, 2, 12)             0         ['conv2d_137[0][0]']
#
#  concatenate_88 (Concatenat  (None, 2, 2, 60)             0         ['dropout_7[0][0]',
#  e)                                                                  'concatenate_87[0][0]']
#
#  batch_normalization_129 (B  (None, 2, 2, 60)             240       ['concatenate_88[0][0]']
#  atchNormalization)
#
#  activation_129 (Activation  (None, 2, 2, 60)             0         ['batch_normalization_129[0][0
#  )                                                                  ]']
#
#  conv2d_138 (Conv2D)         (None, 2, 2, 48)             2928      ['activation_129[0][0]']
#
#  dropout_8 (Dropout)         (None, 2, 2, 48)             0         ['conv2d_138[0][0]']
#
#  batch_normalization_130 (B  (None, 2, 2, 48)             192       ['dropout_8[0][0]']
#  atchNormalization)
#
#  activation_130 (Activation  (None, 2, 2, 48)             0         ['batch_normalization_130[0][0
#  )                                                                  ]']
#
#  conv2d_139 (Conv2D)         (None, 2, 2, 12)             5196      ['activation_130[0][0]']
#
#  dropout_9 (Dropout)         (None, 2, 2, 12)             0         ['conv2d_139[0][0]']
#
#  concatenate_89 (Concatenat  (None, 2, 2, 72)             0         ['dropout_9[0][0]',
#  e)                                                                  'concatenate_88[0][0]']
#
#  batch_normalization_131 (B  (None, 2, 2, 72)             288       ['concatenate_89[0][0]']
#  atchNormalization)
#
#  activation_131 (Activation  (None, 2, 2, 72)             0         ['batch_normalization_131[0][0
#  )                                                                  ]']
#
#  conv2d_140 (Conv2D)         (None, 2, 2, 48)             3504      ['activation_131[0][0]']
#
#  dropout_10 (Dropout)        (None, 2, 2, 48)             0         ['conv2d_140[0][0]']
#
#  batch_normalization_132 (B  (None, 2, 2, 48)             192       ['dropout_10[0][0]']
#  atchNormalization)
#
#  activation_132 (Activation  (None, 2, 2, 48)             0         ['batch_normalization_132[0][0
#  )                                                                  ]']
#
#  conv2d_141 (Conv2D)         (None, 2, 2, 12)             5196      ['activation_132[0][0]']
#
#  dropout_11 (Dropout)        (None, 2, 2, 12)             0         ['conv2d_141[0][0]']
#
#  concatenate_90 (Concatenat  (None, 2, 2, 84)             0         ['dropout_11[0][0]',
#  e)                                                                  'concatenate_89[0][0]']
#
#  batch_normalization_133 (B  (None, 2, 2, 84)             336       ['concatenate_90[0][0]']
#  atchNormalization)
#
#  activation_133 (Activation  (None, 2, 2, 84)             0         ['batch_normalization_133[0][0
#  )                                                                  ]']
#
#  conv2d_142 (Conv2D)         (None, 2, 2, 48)             4080      ['activation_133[0][0]']
#
#  dropout_12 (Dropout)        (None, 2, 2, 48)             0         ['conv2d_142[0][0]']
#
#  batch_normalization_134 (B  (None, 2, 2, 48)             192       ['dropout_12[0][0]']
#  atchNormalization)
#
#  activation_134 (Activation  (None, 2, 2, 48)             0         ['batch_normalization_134[0][0
#  )                                                                  ]']
#
#  conv2d_143 (Conv2D)         (None, 2, 2, 12)             5196      ['activation_134[0][0]']
#
#  dropout_13 (Dropout)        (None, 2, 2, 12)             0         ['conv2d_143[0][0]']
#
#  concatenate_91 (Concatenat  (None, 2, 2, 96)             0         ['dropout_13[0][0]',
#  e)                                                                  'concatenate_90[0][0]']
#
#  batch_normalization_135 (B  (None, 2, 2, 96)             384       ['concatenate_91[0][0]']
#  atchNormalization)
#
#  activation_135 (Activation  (None, 2, 2, 96)             0         ['batch_normalization_135[0][0
#  )                                                                  ]']
#
#  conv2d_144 (Conv2D)         (None, 2, 2, 48)             4656      ['activation_135[0][0]']
#
#  dropout_14 (Dropout)        (None, 2, 2, 48)             0         ['conv2d_144[0][0]']
#
#  average_pooling2d_17 (Aver  (None, 1, 1, 48)             0         ['dropout_14[0][0]']
#  agePooling2D)
#
#  batch_normalization_136 (B  (None, 1, 1, 48)             192       ['average_pooling2d_17[0][0]']
#  atchNormalization)
#
#  activation_136 (Activation  (None, 1, 1, 48)             0         ['batch_normalization_136[0][0
#  )                                                                  ]']
#
#  conv2d_145 (Conv2D)         (None, 1, 1, 48)             2352      ['activation_136[0][0]']
#
#  dropout_15 (Dropout)        (None, 1, 1, 48)             0         ['conv2d_145[0][0]']
#
#  batch_normalization_137 (B  (None, 1, 1, 48)             192       ['dropout_15[0][0]']
#  atchNormalization)
#
#  activation_137 (Activation  (None, 1, 1, 48)             0         ['batch_normalization_137[0][0
#  )                                                                  ]']
#
#  conv2d_146 (Conv2D)         (None, 1, 1, 12)             5196      ['activation_137[0][0]']
#
#  dropout_16 (Dropout)        (None, 1, 1, 12)             0         ['conv2d_146[0][0]']
#
#  concatenate_92 (Concatenat  (None, 1, 1, 60)             0         ['dropout_16[0][0]',
#  e)                                                                  'average_pooling2d_17[0][0]']
#
#  batch_normalization_138 (B  (None, 1, 1, 60)             240       ['concatenate_92[0][0]']
#  atchNormalization)
#
#  activation_138 (Activation  (None, 1, 1, 60)             0         ['batch_normalization_138[0][0
#  )                                                                  ]']
#
#  conv2d_147 (Conv2D)         (None, 1, 1, 48)             2928      ['activation_138[0][0]']
#
#  dropout_17 (Dropout)        (None, 1, 1, 48)             0         ['conv2d_147[0][0]']
#
#  batch_normalization_139 (B  (None, 1, 1, 48)             192       ['dropout_17[0][0]']
#  atchNormalization)
#
#  activation_139 (Activation  (None, 1, 1, 48)             0         ['batch_normalization_139[0][0
#  )                                                                  ]']
#
#  conv2d_148 (Conv2D)         (None, 1, 1, 12)             5196      ['activation_139[0][0]']
#
#  dropout_18 (Dropout)        (None, 1, 1, 12)             0         ['conv2d_148[0][0]']
#
#  concatenate_93 (Concatenat  (None, 1, 1, 72)             0         ['dropout_18[0][0]',
#  e)                                                                  'concatenate_92[0][0]']
#
#  batch_normalization_140 (B  (None, 1, 1, 72)             288       ['concatenate_93[0][0]']
#  atchNormalization)
#
#  activation_140 (Activation  (None, 1, 1, 72)             0         ['batch_normalization_140[0][0
#  )                                                                  ]']
#
#  conv2d_149 (Conv2D)         (None, 1, 1, 48)             3504      ['activation_140[0][0]']
#
#  dropout_19 (Dropout)        (None, 1, 1, 48)             0         ['conv2d_149[0][0]']
#
#  batch_normalization_141 (B  (None, 1, 1, 48)             192       ['dropout_19[0][0]']
#  atchNormalization)
#
#  activation_141 (Activation  (None, 1, 1, 48)             0         ['batch_normalization_141[0][0
#  )                                                                  ]']
#
#  conv2d_150 (Conv2D)         (None, 1, 1, 12)             5196      ['activation_141[0][0]']
#
#  dropout_20 (Dropout)        (None, 1, 1, 12)             0         ['conv2d_150[0][0]']
#
#  concatenate_94 (Concatenat  (None, 1, 1, 84)             0         ['dropout_20[0][0]',
#  e)                                                                  'concatenate_93[0][0]']
#
#  batch_normalization_142 (B  (None, 1, 1, 84)             336       ['concatenate_94[0][0]']
#  atchNormalization)
#
#  activation_142 (Activation  (None, 1, 1, 84)             0         ['batch_normalization_142[0][0
#  )                                                                  ]']
#
#  conv2d_151 (Conv2D)         (None, 1, 1, 48)             4080      ['activation_142[0][0]']
#
#  dropout_21 (Dropout)        (None, 1, 1, 48)             0         ['conv2d_151[0][0]']
#
#  batch_normalization_143 (B  (None, 1, 1, 48)             192       ['dropout_21[0][0]']
#  atchNormalization)
#
#  activation_143 (Activation  (None, 1, 1, 48)             0         ['batch_normalization_143[0][0
#  )                                                                  ]']
#
#  conv2d_152 (Conv2D)         (None, 1, 1, 12)             5196      ['activation_143[0][0]']
#
#  dropout_22 (Dropout)        (None, 1, 1, 12)             0         ['conv2d_152[0][0]']
#
#  concatenate_95 (Concatenat  (None, 1, 1, 96)             0         ['dropout_22[0][0]',
#  e)                                                                  'concatenate_94[0][0]']
#
#  batch_normalization_144 (B  (None, 1, 1, 96)             384       ['concatenate_95[0][0]']
#  atchNormalization)
#
#  activation_144 (Activation  (None, 1, 1, 96)             0         ['batch_normalization_144[0][0
#  )                                                                  ]']
#
#  conv2d_153 (Conv2D)         (None, 1, 1, 48)             4656      ['activation_144[0][0]']
#
#  dropout_23 (Dropout)        (None, 1, 1, 48)             0         ['conv2d_153[0][0]']
#
#  batch_normalization_145 (B  (None, 1, 1, 48)             192       ['dropout_23[0][0]']
#  atchNormalization)
#
#  activation_145 (Activation  (None, 1, 1, 48)             0         ['batch_normalization_145[0][0
#  )                                                                  ]']
#
#  conv2d_154 (Conv2D)         (None, 1, 1, 12)             5196      ['activation_145[0][0]']
#
#  dropout_24 (Dropout)        (None, 1, 1, 12)             0         ['conv2d_154[0][0]']
#
#  concatenate_96 (Concatenat  (None, 1, 1, 108)            0         ['dropout_24[0][0]',
#  e)                                                                  'concatenate_95[0][0]']
#
#  batch_normalization_146 (B  (None, 1, 1, 108)            432       ['concatenate_96[0][0]']
#  atchNormalization)
#
#  activation_146 (Activation  (None, 1, 1, 108)            0         ['batch_normalization_146[0][0
#  )                                                                  ]']
#
#  conv2d_155 (Conv2D)         (None, 1, 1, 48)             5232      ['activation_146[0][0]']
#
#  dropout_25 (Dropout)        (None, 1, 1, 48)             0         ['conv2d_155[0][0]']
#
#  batch_normalization_147 (B  (None, 1, 1, 48)             192       ['dropout_25[0][0]']
#  atchNormalization)
#
#  activation_147 (Activation  (None, 1, 1, 48)             0         ['batch_normalization_147[0][0
#  )                                                                  ]']
#
#  conv2d_156 (Conv2D)         (None, 1, 1, 12)             5196      ['activation_147[0][0]']
#
#  dropout_26 (Dropout)        (None, 1, 1, 12)             0         ['conv2d_156[0][0]']
#
#  concatenate_97 (Concatenat  (None, 1, 1, 120)            0         ['dropout_26[0][0]',
#  e)                                                                  'concatenate_96[0][0]']
#
#  batch_normalization_148 (B  (None, 1, 1, 120)            480       ['concatenate_97[0][0]']
#  atchNormalization)
#
#  activation_148 (Activation  (None, 1, 1, 120)            0         ['batch_normalization_148[0][0
#  )                                                                  ]']
#
#  conv2d_157 (Conv2D)         (None, 1, 1, 48)             5808      ['activation_148[0][0]']
#
#  dropout_27 (Dropout)        (None, 1, 1, 48)             0         ['conv2d_157[0][0]']
#
#  batch_normalization_149 (B  (None, 1, 1, 48)             192       ['dropout_27[0][0]']
#  atchNormalization)
#
#  activation_149 (Activation  (None, 1, 1, 48)             0         ['batch_normalization_149[0][0
#  )                                                                  ]']
#
#  conv2d_158 (Conv2D)         (None, 1, 1, 12)             5196      ['activation_149[0][0]']
#
#  dropout_28 (Dropout)        (None, 1, 1, 12)             0         ['conv2d_158[0][0]']
#
#  concatenate_98 (Concatenat  (None, 1, 1, 132)            0         ['dropout_28[0][0]',
#  e)                                                                  'concatenate_97[0][0]']
#
#  batch_normalization_150 (B  (None, 1, 1, 132)            528       ['concatenate_98[0][0]']
#  atchNormalization)
#
#  activation_150 (Activation  (None, 1, 1, 132)            0         ['batch_normalization_150[0][0
#  )                                                                  ]']
#
#  conv2d_159 (Conv2D)         (None, 1, 1, 48)             6384      ['activation_150[0][0]']
#
#  dropout_29 (Dropout)        (None, 1, 1, 48)             0         ['conv2d_159[0][0]']
#
#  batch_normalization_151 (B  (None, 1, 1, 48)             192       ['dropout_29[0][0]']
#  atchNormalization)
#
#  activation_151 (Activation  (None, 1, 1, 48)             0         ['batch_normalization_151[0][0
#  )                                                                  ]']
#
#  conv2d_160 (Conv2D)         (None, 1, 1, 12)             5196      ['activation_151[0][0]']
#
#  dropout_30 (Dropout)        (None, 1, 1, 12)             0         ['conv2d_160[0][0]']
#
#  concatenate_99 (Concatenat  (None, 1, 1, 144)            0         ['dropout_30[0][0]',
#  e)                                                                  'concatenate_98[0][0]']
#
#  batch_normalization_152 (B  (None, 1, 1, 144)            576       ['concatenate_99[0][0]']
#  atchNormalization)
#
#  activation_152 (Activation  (None, 1, 1, 144)            0         ['batch_normalization_152[0][0
#  )                                                                  ]']
#
#  conv2d_161 (Conv2D)         (None, 1, 1, 48)             6960      ['activation_152[0][0]']
#
#  dropout_31 (Dropout)        (None, 1, 1, 48)             0         ['conv2d_161[0][0]']
#
#  batch_normalization_153 (B  (None, 1, 1, 48)             192       ['dropout_31[0][0]']
#  atchNormalization)
#
#  activation_153 (Activation  (None, 1, 1, 48)             0         ['batch_normalization_153[0][0
#  )                                                                  ]']
#
#  conv2d_162 (Conv2D)         (None, 1, 1, 12)             5196      ['activation_153[0][0]']
#
#  dropout_32 (Dropout)        (None, 1, 1, 12)             0         ['conv2d_162[0][0]']
#
#  concatenate_100 (Concatena  (None, 1, 1, 156)            0         ['dropout_32[0][0]',
#  te)                                                                 'concatenate_99[0][0]']
#
#  batch_normalization_154 (B  (None, 1, 1, 156)            624       ['concatenate_100[0][0]']
#  atchNormalization)
#
#  activation_154 (Activation  (None, 1, 1, 156)            0         ['batch_normalization_154[0][0
#  )                                                                  ]']
#
#  conv2d_163 (Conv2D)         (None, 1, 1, 48)             7536      ['activation_154[0][0]']
#
#  dropout_33 (Dropout)        (None, 1, 1, 48)             0         ['conv2d_163[0][0]']
#
#  batch_normalization_155 (B  (None, 1, 1, 48)             192       ['dropout_33[0][0]']
#  atchNormalization)
#
#  activation_155 (Activation  (None, 1, 1, 48)             0         ['batch_normalization_155[0][0
#  )                                                                  ]']
#
#  conv2d_164 (Conv2D)         (None, 1, 1, 12)             5196      ['activation_155[0][0]']
#
#  dropout_34 (Dropout)        (None, 1, 1, 12)             0         ['conv2d_164[0][0]']
#
#  concatenate_101 (Concatena  (None, 1, 1, 168)            0         ['dropout_34[0][0]',
#  te)                                                                 'concatenate_100[0][0]']
#
#  batch_normalization_156 (B  (None, 1, 1, 168)            672       ['concatenate_101[0][0]']
#  atchNormalization)
#
#  activation_156 (Activation  (None, 1, 1, 168)            0         ['batch_normalization_156[0][0
#  )                                                                  ]']
#
#  conv2d_165 (Conv2D)         (None, 1, 1, 48)             8112      ['activation_156[0][0]']
#
#  dropout_35 (Dropout)        (None, 1, 1, 48)             0         ['conv2d_165[0][0]']
#
#  batch_normalization_157 (B  (None, 1, 1, 48)             192       ['dropout_35[0][0]']
#  atchNormalization)
#
#  activation_157 (Activation  (None, 1, 1, 48)             0         ['batch_normalization_157[0][0
#  )                                                                  ]']
#
#  conv2d_166 (Conv2D)         (None, 1, 1, 12)             5196      ['activation_157[0][0]']
#
#  dropout_36 (Dropout)        (None, 1, 1, 12)             0         ['conv2d_166[0][0]']
#
#  concatenate_102 (Concatena  (None, 1, 1, 180)            0         ['dropout_36[0][0]',
#  te)                                                                 'concatenate_101[0][0]']
#
#  batch_normalization_158 (B  (None, 1, 1, 180)            720       ['concatenate_102[0][0]']
#  atchNormalization)
#
#  activation_158 (Activation  (None, 1, 1, 180)            0         ['batch_normalization_158[0][0
#  )                                                                  ]']
#
#  conv2d_167 (Conv2D)         (None, 1, 1, 48)             8688      ['activation_158[0][0]']
#
#  dropout_37 (Dropout)        (None, 1, 1, 48)             0         ['conv2d_167[0][0]']
#
#  batch_normalization_159 (B  (None, 1, 1, 48)             192       ['dropout_37[0][0]']
#  atchNormalization)
#
#  activation_159 (Activation  (None, 1, 1, 48)             0         ['batch_normalization_159[0][0
#  )                                                                  ]']
#
#  conv2d_168 (Conv2D)         (None, 1, 1, 12)             5196      ['activation_159[0][0]']
#
#  dropout_38 (Dropout)        (None, 1, 1, 12)             0         ['conv2d_168[0][0]']
#
#  concatenate_103 (Concatena  (None, 1, 1, 192)            0         ['dropout_38[0][0]',
#  te)                                                                 'concatenate_102[0][0]']
#
#  batch_normalization_160 (B  (None, 1, 1, 192)            768       ['concatenate_103[0][0]']
#  atchNormalization)
#
#  activation_160 (Activation  (None, 1, 1, 192)            0         ['batch_normalization_160[0][0
#  )                                                                  ]']
#
#  conv2d_169 (Conv2D)         (None, 1, 1, 96)             18528     ['activation_160[0][0]']
#
#  dropout_39 (Dropout)        (None, 1, 1, 96)             0         ['conv2d_169[0][0]']
#
#  average_pooling2d_18 (Aver  (None, 1, 1, 96)             0         ['dropout_39[0][0]']
#  agePooling2D)
#
#  batch_normalization_161 (B  (None, 1, 1, 96)             384       ['average_pooling2d_18[0][0]']
#  atchNormalization)
#
#  activation_161 (Activation  (None, 1, 1, 96)             0         ['batch_normalization_161[0][0
#  )                                                                  ]']
#
#  conv2d_170 (Conv2D)         (None, 1, 1, 48)             4656      ['activation_161[0][0]']
#
#  dropout_40 (Dropout)        (None, 1, 1, 48)             0         ['conv2d_170[0][0]']
#
#  batch_normalization_162 (B  (None, 1, 1, 48)             192       ['dropout_40[0][0]']
#  atchNormalization)
# ...
#
#  conv2d_205 (Conv2D)         (None, 1, 1, 12)             5196      ['activation_196[0][0]']
#
#  dropout_75 (Dropout)        (None, 1, 1, 12)             0         ['conv2d_205[0][0]']
#
#  concatenate_121 (Concatena  (None, 1, 1, 312)            0         ['dropout_75[0][0]',
#  te)                                                                 'concatenate_120[0][0]']
#
#  batch_normalization_197 (B  (None, 1, 1, 312)            1248      ['concatenate_121[0][0]']
#  atchNormalization)
#
#  activation_197 (Activation  (None, 1, 1, 312)            0         ['batch_normalization_197[0][0
#  )                                                                  ]']
#
#  conv2d_206 (Conv2D)         (None, 1, 1, 48)             15024     ['activation_197[0][0]']
#
#  dropout_76 (Dropout)        (None, 1, 1, 48)             0         ['conv2d_206[0][0]']
#
#  batch_normalization_198 (B  (None, 1, 1, 48)             192       ['dropout_76[0][0]']
#  atchNormalization)
#
#  activation_198 (Activation  (None, 1, 1, 48)             0         ['batch_normalization_198[0][0
#  )                                                                  ]']
#
#  conv2d_207 (Conv2D)         (None, 1, 1, 12)             5196      ['activation_198[0][0]']
#
#  dropout_77 (Dropout)        (None, 1, 1, 12)             0         ['conv2d_207[0][0]']
#
#  concatenate_122 (Concatena  (None, 1, 1, 324)            0         ['dropout_77[0][0]',
#  te)                                                                 'concatenate_121[0][0]']
#
#  batch_normalization_199 (B  (None, 1, 1, 324)            1296      ['concatenate_122[0][0]']
#  atchNormalization)
#
#  activation_199 (Activation  (None, 1, 1, 324)            0         ['batch_normalization_199[0][0
#  )                                                                  ]']
#
#  conv2d_208 (Conv2D)         (None, 1, 1, 48)             15600     ['activation_199[0][0]']
#
#  dropout_78 (Dropout)        (None, 1, 1, 48)             0         ['conv2d_208[0][0]']
#
#  batch_normalization_200 (B  (None, 1, 1, 48)             192       ['dropout_78[0][0]']
#  atchNormalization)
#
#  activation_200 (Activation  (None, 1, 1, 48)             0         ['batch_normalization_200[0][0
#  )                                                                  ]']
#
#  conv2d_209 (Conv2D)         (None, 1, 1, 12)             5196      ['activation_200[0][0]']
#
#  dropout_79 (Dropout)        (None, 1, 1, 12)             0         ['conv2d_209[0][0]']
#
#  concatenate_123 (Concatena  (None, 1, 1, 336)            0         ['dropout_79[0][0]',
#  te)                                                                 'concatenate_122[0][0]']
#
#  batch_normalization_201 (B  (None, 1, 1, 336)            1344      ['concatenate_123[0][0]']
#  atchNormalization)
#
#  activation_201 (Activation  (None, 1, 1, 336)            0         ['batch_normalization_201[0][0
#  )                                                                  ]']
#
#  conv2d_210 (Conv2D)         (None, 1, 1, 48)             16176     ['activation_201[0][0]']
#
#  dropout_80 (Dropout)        (None, 1, 1, 48)             0         ['conv2d_210[0][0]']
#
#  batch_normalization_202 (B  (None, 1, 1, 48)             192       ['dropout_80[0][0]']
#  atchNormalization)
#
#  activation_202 (Activation  (None, 1, 1, 48)             0         ['batch_normalization_202[0][0
#  )                                                                  ]']
#
#  conv2d_211 (Conv2D)         (None, 1, 1, 12)             5196      ['activation_202[0][0]']
#
#  dropout_81 (Dropout)        (None, 1, 1, 12)             0         ['conv2d_211[0][0]']
#
#  concatenate_124 (Concatena  (None, 1, 1, 348)            0         ['dropout_81[0][0]',
#  te)                                                                 'concatenate_123[0][0]']
#
#  batch_normalization_203 (B  (None, 1, 1, 348)            1392      ['concatenate_124[0][0]']
#  atchNormalization)
#
#  activation_203 (Activation  (None, 1, 1, 348)            0         ['batch_normalization_203[0][0
#  )                                                                  ]']
#
#  conv2d_212 (Conv2D)         (None, 1, 1, 48)             16752     ['activation_203[0][0]']
#
#  dropout_82 (Dropout)        (None, 1, 1, 48)             0         ['conv2d_212[0][0]']
#
#  batch_normalization_204 (B  (None, 1, 1, 48)             192       ['dropout_82[0][0]']
#  atchNormalization)
#
#  activation_204 (Activation  (None, 1, 1, 48)             0         ['batch_normalization_204[0][0
#  )                                                                  ]']
#
#  conv2d_213 (Conv2D)         (None, 1, 1, 12)             5196      ['activation_204[0][0]']
#
#  dropout_83 (Dropout)        (None, 1, 1, 12)             0         ['conv2d_213[0][0]']
#
#  concatenate_125 (Concatena  (None, 1, 1, 360)            0         ['dropout_83[0][0]',
#  te)                                                                 'concatenate_124[0][0]']
#
#  batch_normalization_205 (B  (None, 1, 1, 360)            1440      ['concatenate_125[0][0]']
#  atchNormalization)
#
#  activation_205 (Activation  (None, 1, 1, 360)            0         ['batch_normalization_205[0][0
#  )                                                                  ]']
#
#  conv2d_214 (Conv2D)         (None, 1, 1, 48)             17328     ['activation_205[0][0]']
#
#  dropout_84 (Dropout)        (None, 1, 1, 48)             0         ['conv2d_214[0][0]']
#
#  batch_normalization_206 (B  (None, 1, 1, 48)             192       ['dropout_84[0][0]']
#  atchNormalization)
#
#  activation_206 (Activation  (None, 1, 1, 48)             0         ['batch_normalization_206[0][0
#  )                                                                  ]']
#
#  conv2d_215 (Conv2D)         (None, 1, 1, 12)             5196      ['activation_206[0][0]']
#
#  dropout_85 (Dropout)        (None, 1, 1, 12)             0         ['conv2d_215[0][0]']
#
#  concatenate_126 (Concatena  (None, 1, 1, 372)            0         ['dropout_85[0][0]',
#  te)                                                                 'concatenate_125[0][0]']
#
#  batch_normalization_207 (B  (None, 1, 1, 372)            1488      ['concatenate_126[0][0]']
#  atchNormalization)
#
#  activation_207 (Activation  (None, 1, 1, 372)            0         ['batch_normalization_207[0][0
#  )                                                                  ]']
#
#  conv2d_216 (Conv2D)         (None, 1, 1, 48)             17904     ['activation_207[0][0]']
#
#  dropout_86 (Dropout)        (None, 1, 1, 48)             0         ['conv2d_216[0][0]']
#
#  batch_normalization_208 (B  (None, 1, 1, 48)             192       ['dropout_86[0][0]']
#  atchNormalization)
#
#  activation_208 (Activation  (None, 1, 1, 48)             0         ['batch_normalization_208[0][0
#  )                                                                  ]']
#
#  conv2d_217 (Conv2D)         (None, 1, 1, 12)             5196      ['activation_208[0][0]']
#
#  dropout_87 (Dropout)        (None, 1, 1, 12)             0         ['conv2d_217[0][0]']
#
#  concatenate_127 (Concatena  (None, 1, 1, 384)            0         ['dropout_87[0][0]',
#  te)                                                                 'concatenate_126[0][0]']
#
#  batch_normalization_209 (B  (None, 1, 1, 384)            1536      ['concatenate_127[0][0]']
#  atchNormalization)
#
#  activation_209 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_209[0][0
#  )                                                                  ]']
#
#  global_average_pooling2d_7  (None, 384)                  0         ['activation_209[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_8 (Dense)             (None, 10)                   3850      ['global_average_pooling2d_7[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 654490 (2.50 MB)
# Trainable params: 634402 (2.42 MB)
# Non-trainable params: 20088 (78.47 KB)
# __________________________________________________________________________________________________

# %%
aug_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])


aug_hist = aug_model.fit(X_train, Y_train, epochs=2, batch_size=32, validation_split=0.1,
                         callbacks=[tf.keras.callbacks.EarlyStopping(patience=5)])
# Out:
# Epoch 1/2
# 1407/1407 [==============================] - 160s 83ms/step - loss: 1.9306 - accuracy: 0.2977 - val_loss: 1.7765 - val_accuracy: 0.3684
# Epoch 2/2
# 1407/1407 [==============================] - 113s 80ms/step - loss: 1.6769 - accuracy: 0.3941 - val_loss: 1.6532 - val_accuracy: 0.4138

# %%
# Model Evaluation
loss, accuracy = aug_model.evaluate(X_test, Y_test, verbose=0)
print("Test Loss: ", loss)
print("Test Accuracy: ", accuracy)
# Out:
# Test Loss:  1.6381686925888062
# Test Accuracy:  0.41920000314712524

# %%
input_shape = (32, 32, 3)
n_classes = 10
blocks = (6, 12, 24)
growth_rate = 12
compression_rate = 0.5
dropout_rate = 0.2
bottleneck = True

# %%
inputs = tf.keras.Input(shape=input_shape)
x = inputs

# %%
# Convolution layer
x = tf.keras.layers.Conv2D(2 * growth_rate, (7, 7), strides=(2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Activation('relu')(x)
x = tf.keras.layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)

# %%
# Dense net
for i, num in enumerate(blocks):
  x = densenet_block(x, num, growth_rate, dropout=dropout_rate, bottleneck=bottleneck)
  if i != len(blocks) - 1:
    x = transition_block(x, compression=compression_rate, dropout=dropout_rate)

x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Activation('relu')(x)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(n_classes, activation='softmax')(x)

# %%
model = tf.keras.Model(inputs=inputs, outputs=x)

# %%
model.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_15 (InputLayer)       [(None, 32, 32, 3)]          0         []
#
#  conv2d_218 (Conv2D)         (None, 16, 16, 24)           3552      ['input_15[0][0]']
#
#  batch_normalization_210 (B  (None, 16, 16, 24)           96        ['conv2d_218[0][0]']
#  atchNormalization)
#
#  activation_210 (Activation  (None, 16, 16, 24)           0         ['batch_normalization_210[0][0
#  )                                                                  ]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 8, 8, 24)             0         ['activation_210[0][0]']
#  g2D)
#
#  batch_normalization_211 (B  (None, 8, 8, 24)             96        ['max_pooling2d_4[0][0]']
#  atchNormalization)
#
#  activation_211 (Activation  (None, 8, 8, 24)             0         ['batch_normalization_211[0][0
#  )                                                                  ]']
#
#  conv2d_219 (Conv2D)         (None, 8, 8, 48)             1200      ['activation_211[0][0]']
#
#  dropout_88 (Dropout)        (None, 8, 8, 48)             0         ['conv2d_219[0][0]']
#
#  batch_normalization_212 (B  (None, 8, 8, 48)             192       ['dropout_88[0][0]']
#  atchNormalization)
#
#  activation_212 (Activation  (None, 8, 8, 48)             0         ['batch_normalization_212[0][0
#  )                                                                  ]']
#
#  conv2d_220 (Conv2D)         (None, 8, 8, 12)             5196      ['activation_212[0][0]']
#
#  dropout_89 (Dropout)        (None, 8, 8, 12)             0         ['conv2d_220[0][0]']
#
#  concatenate_128 (Concatena  (None, 8, 8, 36)             0         ['dropout_89[0][0]',
#  te)                                                                 'max_pooling2d_4[0][0]']
#
#  batch_normalization_213 (B  (None, 8, 8, 36)             144       ['concatenate_128[0][0]']
#  atchNormalization)
#
#  activation_213 (Activation  (None, 8, 8, 36)             0         ['batch_normalization_213[0][0
#  )                                                                  ]']
#
#  conv2d_221 (Conv2D)         (None, 8, 8, 48)             1776      ['activation_213[0][0]']
#
#  dropout_90 (Dropout)        (None, 8, 8, 48)             0         ['conv2d_221[0][0]']
#
#  batch_normalization_214 (B  (None, 8, 8, 48)             192       ['dropout_90[0][0]']
#  atchNormalization)
#
#  activation_214 (Activation  (None, 8, 8, 48)             0         ['batch_normalization_214[0][0
#  )                                                                  ]']
#
#  conv2d_222 (Conv2D)         (None, 8, 8, 12)             5196      ['activation_214[0][0]']
#
#  dropout_91 (Dropout)        (None, 8, 8, 12)             0         ['conv2d_222[0][0]']
#
#  concatenate_129 (Concatena  (None, 8, 8, 48)             0         ['dropout_91[0][0]',
#  te)                                                                 'concatenate_128[0][0]']
#
#  batch_normalization_215 (B  (None, 8, 8, 48)             192       ['concatenate_129[0][0]']
#  atchNormalization)
#
#  activation_215 (Activation  (None, 8, 8, 48)             0         ['batch_normalization_215[0][0
#  )                                                                  ]']
#
#  conv2d_223 (Conv2D)         (None, 8, 8, 48)             2352      ['activation_215[0][0]']
#
#  dropout_92 (Dropout)        (None, 8, 8, 48)             0         ['conv2d_223[0][0]']
#
#  batch_normalization_216 (B  (None, 8, 8, 48)             192       ['dropout_92[0][0]']
#  atchNormalization)
#
#  activation_216 (Activation  (None, 8, 8, 48)             0         ['batch_normalization_216[0][0
#  )                                                                  ]']
#
#  conv2d_224 (Conv2D)         (None, 8, 8, 12)             5196      ['activation_216[0][0]']
#
#  dropout_93 (Dropout)        (None, 8, 8, 12)             0         ['conv2d_224[0][0]']
#
#  concatenate_130 (Concatena  (None, 8, 8, 60)             0         ['dropout_93[0][0]',
#  te)                                                                 'concatenate_129[0][0]']
#
#  batch_normalization_217 (B  (None, 8, 8, 60)             240       ['concatenate_130[0][0]']
#  atchNormalization)
#
#  activation_217 (Activation  (None, 8, 8, 60)             0         ['batch_normalization_217[0][0
#  )                                                                  ]']
#
#  conv2d_225 (Conv2D)         (None, 8, 8, 48)             2928      ['activation_217[0][0]']
#
#  dropout_94 (Dropout)        (None, 8, 8, 48)             0         ['conv2d_225[0][0]']
#
#  batch_normalization_218 (B  (None, 8, 8, 48)             192       ['dropout_94[0][0]']
#  atchNormalization)
#
#  activation_218 (Activation  (None, 8, 8, 48)             0         ['batch_normalization_218[0][0
#  )                                                                  ]']
#
#  conv2d_226 (Conv2D)         (None, 8, 8, 12)             5196      ['activation_218[0][0]']
#
#  dropout_95 (Dropout)        (None, 8, 8, 12)             0         ['conv2d_226[0][0]']
#
#  concatenate_131 (Concatena  (None, 8, 8, 72)             0         ['dropout_95[0][0]',
#  te)                                                                 'concatenate_130[0][0]']
#
#  batch_normalization_219 (B  (None, 8, 8, 72)             288       ['concatenate_131[0][0]']
#  atchNormalization)
#
#  activation_219 (Activation  (None, 8, 8, 72)             0         ['batch_normalization_219[0][0
#  )                                                                  ]']
#
#  conv2d_227 (Conv2D)         (None, 8, 8, 48)             3504      ['activation_219[0][0]']
#
#  dropout_96 (Dropout)        (None, 8, 8, 48)             0         ['conv2d_227[0][0]']
#
#  batch_normalization_220 (B  (None, 8, 8, 48)             192       ['dropout_96[0][0]']
#  atchNormalization)
#
#  activation_220 (Activation  (None, 8, 8, 48)             0         ['batch_normalization_220[0][0
#  )                                                                  ]']
#
#  conv2d_228 (Conv2D)         (None, 8, 8, 12)             5196      ['activation_220[0][0]']
#
#  dropout_97 (Dropout)        (None, 8, 8, 12)             0         ['conv2d_228[0][0]']
#
#  concatenate_132 (Concatena  (None, 8, 8, 84)             0         ['dropout_97[0][0]',
#  te)                                                                 'concatenate_131[0][0]']
#
#  batch_normalization_221 (B  (None, 8, 8, 84)             336       ['concatenate_132[0][0]']
#  atchNormalization)
#
#  activation_221 (Activation  (None, 8, 8, 84)             0         ['batch_normalization_221[0][0
#  )                                                                  ]']
#
#  conv2d_229 (Conv2D)         (None, 8, 8, 48)             4080      ['activation_221[0][0]']
#
#  dropout_98 (Dropout)        (None, 8, 8, 48)             0         ['conv2d_229[0][0]']
#
#  batch_normalization_222 (B  (None, 8, 8, 48)             192       ['dropout_98[0][0]']
#  atchNormalization)
#
#  activation_222 (Activation  (None, 8, 8, 48)             0         ['batch_normalization_222[0][0
#  )                                                                  ]']
#
#  conv2d_230 (Conv2D)         (None, 8, 8, 12)             5196      ['activation_222[0][0]']
#
#  dropout_99 (Dropout)        (None, 8, 8, 12)             0         ['conv2d_230[0][0]']
#
#  concatenate_133 (Concatena  (None, 8, 8, 96)             0         ['dropout_99[0][0]',
#  te)                                                                 'concatenate_132[0][0]']
#
#  batch_normalization_223 (B  (None, 8, 8, 96)             384       ['concatenate_133[0][0]']
#  atchNormalization)
#
#  activation_223 (Activation  (None, 8, 8, 96)             0         ['batch_normalization_223[0][0
#  )                                                                  ]']
#
#  conv2d_231 (Conv2D)         (None, 8, 8, 48)             4656      ['activation_223[0][0]']
#
#  dropout_100 (Dropout)       (None, 8, 8, 48)             0         ['conv2d_231[0][0]']
#
#  average_pooling2d_19 (Aver  (None, 4, 4, 48)             0         ['dropout_100[0][0]']
#  agePooling2D)
#
#  batch_normalization_224 (B  (None, 4, 4, 48)             192       ['average_pooling2d_19[0][0]']
#  atchNormalization)
#
#  activation_224 (Activation  (None, 4, 4, 48)             0         ['batch_normalization_224[0][0
#  )                                                                  ]']
#
#  conv2d_232 (Conv2D)         (None, 4, 4, 48)             2352      ['activation_224[0][0]']
#
#  dropout_101 (Dropout)       (None, 4, 4, 48)             0         ['conv2d_232[0][0]']
#
#  batch_normalization_225 (B  (None, 4, 4, 48)             192       ['dropout_101[0][0]']
#  atchNormalization)
#
#  activation_225 (Activation  (None, 4, 4, 48)             0         ['batch_normalization_225[0][0
#  )                                                                  ]']
#
#  conv2d_233 (Conv2D)         (None, 4, 4, 12)             5196      ['activation_225[0][0]']
#
#  dropout_102 (Dropout)       (None, 4, 4, 12)             0         ['conv2d_233[0][0]']
#
#  concatenate_134 (Concatena  (None, 4, 4, 60)             0         ['dropout_102[0][0]',
#  te)                                                                 'average_pooling2d_19[0][0]']
#
#  batch_normalization_226 (B  (None, 4, 4, 60)             240       ['concatenate_134[0][0]']
#  atchNormalization)
#
#  activation_226 (Activation  (None, 4, 4, 60)             0         ['batch_normalization_226[0][0
#  )                                                                  ]']
#
#  conv2d_234 (Conv2D)         (None, 4, 4, 48)             2928      ['activation_226[0][0]']
#
#  dropout_103 (Dropout)       (None, 4, 4, 48)             0         ['conv2d_234[0][0]']
#
#  batch_normalization_227 (B  (None, 4, 4, 48)             192       ['dropout_103[0][0]']
#  atchNormalization)
#
#  activation_227 (Activation  (None, 4, 4, 48)             0         ['batch_normalization_227[0][0
#  )                                                                  ]']
#
#  conv2d_235 (Conv2D)         (None, 4, 4, 12)             5196      ['activation_227[0][0]']
#
#  dropout_104 (Dropout)       (None, 4, 4, 12)             0         ['conv2d_235[0][0]']
#
#  concatenate_135 (Concatena  (None, 4, 4, 72)             0         ['dropout_104[0][0]',
#  te)                                                                 'concatenate_134[0][0]']
#
#  batch_normalization_228 (B  (None, 4, 4, 72)             288       ['concatenate_135[0][0]']
#  atchNormalization)
#
#  activation_228 (Activation  (None, 4, 4, 72)             0         ['batch_normalization_228[0][0
#  )                                                                  ]']
#
#  conv2d_236 (Conv2D)         (None, 4, 4, 48)             3504      ['activation_228[0][0]']
#
#  dropout_105 (Dropout)       (None, 4, 4, 48)             0         ['conv2d_236[0][0]']
#
#  batch_normalization_229 (B  (None, 4, 4, 48)             192       ['dropout_105[0][0]']
#  atchNormalization)
#
#  activation_229 (Activation  (None, 4, 4, 48)             0         ['batch_normalization_229[0][0
#  )                                                                  ]']
#
#  conv2d_237 (Conv2D)         (None, 4, 4, 12)             5196      ['activation_229[0][0]']
#
#  dropout_106 (Dropout)       (None, 4, 4, 12)             0         ['conv2d_237[0][0]']
#
#  concatenate_136 (Concatena  (None, 4, 4, 84)             0         ['dropout_106[0][0]',
#  te)                                                                 'concatenate_135[0][0]']
#
#  batch_normalization_230 (B  (None, 4, 4, 84)             336       ['concatenate_136[0][0]']
#  atchNormalization)
#
#  activation_230 (Activation  (None, 4, 4, 84)             0         ['batch_normalization_230[0][0
#  )                                                                  ]']
#
#  conv2d_238 (Conv2D)         (None, 4, 4, 48)             4080      ['activation_230[0][0]']
#
#  dropout_107 (Dropout)       (None, 4, 4, 48)             0         ['conv2d_238[0][0]']
#
#  batch_normalization_231 (B  (None, 4, 4, 48)             192       ['dropout_107[0][0]']
#  atchNormalization)
#
#  activation_231 (Activation  (None, 4, 4, 48)             0         ['batch_normalization_231[0][0
#  )                                                                  ]']
#
#  conv2d_239 (Conv2D)         (None, 4, 4, 12)             5196      ['activation_231[0][0]']
#
#  dropout_108 (Dropout)       (None, 4, 4, 12)             0         ['conv2d_239[0][0]']
#
#  concatenate_137 (Concatena  (None, 4, 4, 96)             0         ['dropout_108[0][0]',
#  te)                                                                 'concatenate_136[0][0]']
#
#  batch_normalization_232 (B  (None, 4, 4, 96)             384       ['concatenate_137[0][0]']
#  atchNormalization)
#
#  activation_232 (Activation  (None, 4, 4, 96)             0         ['batch_normalization_232[0][0
#  )                                                                  ]']
#
#  conv2d_240 (Conv2D)         (None, 4, 4, 48)             4656      ['activation_232[0][0]']
#
#  dropout_109 (Dropout)       (None, 4, 4, 48)             0         ['conv2d_240[0][0]']
#
#  batch_normalization_233 (B  (None, 4, 4, 48)             192       ['dropout_109[0][0]']
#  atchNormalization)
#
#  activation_233 (Activation  (None, 4, 4, 48)             0         ['batch_normalization_233[0][0
#  )                                                                  ]']
#
#  conv2d_241 (Conv2D)         (None, 4, 4, 12)             5196      ['activation_233[0][0]']
#
#  dropout_110 (Dropout)       (None, 4, 4, 12)             0         ['conv2d_241[0][0]']
#
#  concatenate_138 (Concatena  (None, 4, 4, 108)            0         ['dropout_110[0][0]',
#  te)                                                                 'concatenate_137[0][0]']
#
#  batch_normalization_234 (B  (None, 4, 4, 108)            432       ['concatenate_138[0][0]']
#  atchNormalization)
#
#  activation_234 (Activation  (None, 4, 4, 108)            0         ['batch_normalization_234[0][0
#  )                                                                  ]']
#
#  conv2d_242 (Conv2D)         (None, 4, 4, 48)             5232      ['activation_234[0][0]']
#
#  dropout_111 (Dropout)       (None, 4, 4, 48)             0         ['conv2d_242[0][0]']
#
#  batch_normalization_235 (B  (None, 4, 4, 48)             192       ['dropout_111[0][0]']
#  atchNormalization)
#
#  activation_235 (Activation  (None, 4, 4, 48)             0         ['batch_normalization_235[0][0
#  )                                                                  ]']
#
#  conv2d_243 (Conv2D)         (None, 4, 4, 12)             5196      ['activation_235[0][0]']
#
#  dropout_112 (Dropout)       (None, 4, 4, 12)             0         ['conv2d_243[0][0]']
#
#  concatenate_139 (Concatena  (None, 4, 4, 120)            0         ['dropout_112[0][0]',
#  te)                                                                 'concatenate_138[0][0]']
#
#  batch_normalization_236 (B  (None, 4, 4, 120)            480       ['concatenate_139[0][0]']
#  atchNormalization)
#
#  activation_236 (Activation  (None, 4, 4, 120)            0         ['batch_normalization_236[0][0
#  )                                                                  ]']
#
#  conv2d_244 (Conv2D)         (None, 4, 4, 48)             5808      ['activation_236[0][0]']
#
#  dropout_113 (Dropout)       (None, 4, 4, 48)             0         ['conv2d_244[0][0]']
#
#  batch_normalization_237 (B  (None, 4, 4, 48)             192       ['dropout_113[0][0]']
#  atchNormalization)
#
#  activation_237 (Activation  (None, 4, 4, 48)             0         ['batch_normalization_237[0][0
#  )                                                                  ]']
#
#  conv2d_245 (Conv2D)         (None, 4, 4, 12)             5196      ['activation_237[0][0]']
#
#  dropout_114 (Dropout)       (None, 4, 4, 12)             0         ['conv2d_245[0][0]']
#
#  concatenate_140 (Concatena  (None, 4, 4, 132)            0         ['dropout_114[0][0]',
#  te)                                                                 'concatenate_139[0][0]']
#
#  batch_normalization_238 (B  (None, 4, 4, 132)            528       ['concatenate_140[0][0]']
#  atchNormalization)
#
#  activation_238 (Activation  (None, 4, 4, 132)            0         ['batch_normalization_238[0][0
#  )                                                                  ]']
#
#  conv2d_246 (Conv2D)         (None, 4, 4, 48)             6384      ['activation_238[0][0]']
#
#  dropout_115 (Dropout)       (None, 4, 4, 48)             0         ['conv2d_246[0][0]']
#
#  batch_normalization_239 (B  (None, 4, 4, 48)             192       ['dropout_115[0][0]']
#  atchNormalization)
#
#  activation_239 (Activation  (None, 4, 4, 48)             0         ['batch_normalization_239[0][0
#  )                                                                  ]']
#
#  conv2d_247 (Conv2D)         (None, 4, 4, 12)             5196      ['activation_239[0][0]']
#
#  dropout_116 (Dropout)       (None, 4, 4, 12)             0         ['conv2d_247[0][0]']
#
#  concatenate_141 (Concatena  (None, 4, 4, 144)            0         ['dropout_116[0][0]',
#  te)                                                                 'concatenate_140[0][0]']
#
#  batch_normalization_240 (B  (None, 4, 4, 144)            576       ['concatenate_141[0][0]']
#  atchNormalization)
#
#  activation_240 (Activation  (None, 4, 4, 144)            0         ['batch_normalization_240[0][0
#  )                                                                  ]']
#
#  conv2d_248 (Conv2D)         (None, 4, 4, 48)             6960      ['activation_240[0][0]']
#
#  dropout_117 (Dropout)       (None, 4, 4, 48)             0         ['conv2d_248[0][0]']
#
#  batch_normalization_241 (B  (None, 4, 4, 48)             192       ['dropout_117[0][0]']
#  atchNormalization)
#
#  activation_241 (Activation  (None, 4, 4, 48)             0         ['batch_normalization_241[0][0
#  )                                                                  ]']
#
#  conv2d_249 (Conv2D)         (None, 4, 4, 12)             5196      ['activation_241[0][0]']
#
#  dropout_118 (Dropout)       (None, 4, 4, 12)             0         ['conv2d_249[0][0]']
#
#  concatenate_142 (Concatena  (None, 4, 4, 156)            0         ['dropout_118[0][0]',
#  te)                                                                 'concatenate_141[0][0]']
#
#  batch_normalization_242 (B  (None, 4, 4, 156)            624       ['concatenate_142[0][0]']
#  atchNormalization)
#
#  activation_242 (Activation  (None, 4, 4, 156)            0         ['batch_normalization_242[0][0
#  )                                                                  ]']
#
#  conv2d_250 (Conv2D)         (None, 4, 4, 48)             7536      ['activation_242[0][0]']
#
#  dropout_119 (Dropout)       (None, 4, 4, 48)             0         ['conv2d_250[0][0]']
#
#  batch_normalization_243 (B  (None, 4, 4, 48)             192       ['dropout_119[0][0]']
#  atchNormalization)
#
#  activation_243 (Activation  (None, 4, 4, 48)             0         ['batch_normalization_243[0][0
#  )                                                                  ]']
#
#  conv2d_251 (Conv2D)         (None, 4, 4, 12)             5196      ['activation_243[0][0]']
#
#  dropout_120 (Dropout)       (None, 4, 4, 12)             0         ['conv2d_251[0][0]']
#
#  concatenate_143 (Concatena  (None, 4, 4, 168)            0         ['dropout_120[0][0]',
#  te)                                                                 'concatenate_142[0][0]']
#
#  batch_normalization_244 (B  (None, 4, 4, 168)            672       ['concatenate_143[0][0]']
#  atchNormalization)
#
#  activation_244 (Activation  (None, 4, 4, 168)            0         ['batch_normalization_244[0][0
#  )                                                                  ]']
#
#  conv2d_252 (Conv2D)         (None, 4, 4, 48)             8112      ['activation_244[0][0]']
#
#  dropout_121 (Dropout)       (None, 4, 4, 48)             0         ['conv2d_252[0][0]']
#
#  batch_normalization_245 (B  (None, 4, 4, 48)             192       ['dropout_121[0][0]']
#  atchNormalization)
#
#  activation_245 (Activation  (None, 4, 4, 48)             0         ['batch_normalization_245[0][0
#  )                                                                  ]']
#
#  conv2d_253 (Conv2D)         (None, 4, 4, 12)             5196      ['activation_245[0][0]']
#
#  dropout_122 (Dropout)       (None, 4, 4, 12)             0         ['conv2d_253[0][0]']
#
#  concatenate_144 (Concatena  (None, 4, 4, 180)            0         ['dropout_122[0][0]',
#  te)                                                                 'concatenate_143[0][0]']
#
#  batch_normalization_246 (B  (None, 4, 4, 180)            720       ['concatenate_144[0][0]']
#  atchNormalization)
#
#  activation_246 (Activation  (None, 4, 4, 180)            0         ['batch_normalization_246[0][0
#  )                                                                  ]']
#
#  conv2d_254 (Conv2D)         (None, 4, 4, 48)             8688      ['activation_246[0][0]']
#
#  dropout_123 (Dropout)       (None, 4, 4, 48)             0         ['conv2d_254[0][0]']
#
#  batch_normalization_247 (B  (None, 4, 4, 48)             192       ['dropout_123[0][0]']
#  atchNormalization)
#
#  activation_247 (Activation  (None, 4, 4, 48)             0         ['batch_normalization_247[0][0
#  )                                                                  ]']
#
#  conv2d_255 (Conv2D)         (None, 4, 4, 12)             5196      ['activation_247[0][0]']
#
#  dropout_124 (Dropout)       (None, 4, 4, 12)             0         ['conv2d_255[0][0]']
#
#  concatenate_145 (Concatena  (None, 4, 4, 192)            0         ['dropout_124[0][0]',
#  te)                                                                 'concatenate_144[0][0]']
#
#  batch_normalization_248 (B  (None, 4, 4, 192)            768       ['concatenate_145[0][0]']
#  atchNormalization)
#
#  activation_248 (Activation  (None, 4, 4, 192)            0         ['batch_normalization_248[0][0
#  )                                                                  ]']
#
#  conv2d_256 (Conv2D)         (None, 4, 4, 96)             18528     ['activation_248[0][0]']
#
#  dropout_125 (Dropout)       (None, 4, 4, 96)             0         ['conv2d_256[0][0]']
#
#  average_pooling2d_20 (Aver  (None, 2, 2, 96)             0         ['dropout_125[0][0]']
#  agePooling2D)
#
#  batch_normalization_249 (B  (None, 2, 2, 96)             384       ['average_pooling2d_20[0][0]']
#  atchNormalization)
#
#  activation_249 (Activation  (None, 2, 2, 96)             0         ['batch_normalization_249[0][0
#  )                                                                  ]']
#
#  conv2d_257 (Conv2D)         (None, 2, 2, 48)             4656      ['activation_249[0][0]']
#
#  dropout_126 (Dropout)       (None, 2, 2, 48)             0         ['conv2d_257[0][0]']
#
#  batch_normalization_250 (B  (None, 2, 2, 48)             192       ['dropout_126[0][0]']
#  atchNormalization)
#
#  activation_250 (Activation  (None, 2, 2, 48)             0         ['batch_normalization_250[0][0
#  )                                                                  ]']
#
#  conv2d_258 (Conv2D)         (None, 2, 2, 12)             5196      ['activation_250[0][0]']
#
#  dropout_127 (Dropout)       (None, 2, 2, 12)             0         ['conv2d_258[0][0]']
#
#  concatenate_146 (Concatena  (None, 2, 2, 108)            0         ['dropout_127[0][0]',
#  te)                                                                 'average_pooling2d_20[0][0]']
#
#  batch_normalization_251 (B  (None, 2, 2, 108)            432       ['concatenate_146[0][0]']
#  atchNormalization)
#
#  activation_251 (Activation  (None, 2, 2, 108)            0         ['batch_normalization_251[0][0
#  )                                                                  ]']
# ...
#
#  conv2d_292 (Conv2D)         (None, 2, 2, 12)             5196      ['activation_284[0][0]']
#
#  dropout_161 (Dropout)       (None, 2, 2, 12)             0         ['conv2d_292[0][0]']
#
#  concatenate_163 (Concatena  (None, 2, 2, 312)            0         ['dropout_161[0][0]',
#  te)                                                                 'concatenate_162[0][0]']
#
#  batch_normalization_285 (B  (None, 2, 2, 312)            1248      ['concatenate_163[0][0]']
#  atchNormalization)
#
#  activation_285 (Activation  (None, 2, 2, 312)            0         ['batch_normalization_285[0][0
#  )                                                                  ]']
#
#  conv2d_293 (Conv2D)         (None, 2, 2, 48)             15024     ['activation_285[0][0]']
#
#  dropout_162 (Dropout)       (None, 2, 2, 48)             0         ['conv2d_293[0][0]']
#
#  batch_normalization_286 (B  (None, 2, 2, 48)             192       ['dropout_162[0][0]']
#  atchNormalization)
#
#  activation_286 (Activation  (None, 2, 2, 48)             0         ['batch_normalization_286[0][0
#  )                                                                  ]']
#
#  conv2d_294 (Conv2D)         (None, 2, 2, 12)             5196      ['activation_286[0][0]']
#
#  dropout_163 (Dropout)       (None, 2, 2, 12)             0         ['conv2d_294[0][0]']
#
#  concatenate_164 (Concatena  (None, 2, 2, 324)            0         ['dropout_163[0][0]',
#  te)                                                                 'concatenate_163[0][0]']
#
#  batch_normalization_287 (B  (None, 2, 2, 324)            1296      ['concatenate_164[0][0]']
#  atchNormalization)
#
#  activation_287 (Activation  (None, 2, 2, 324)            0         ['batch_normalization_287[0][0
#  )                                                                  ]']
#
#  conv2d_295 (Conv2D)         (None, 2, 2, 48)             15600     ['activation_287[0][0]']
#
#  dropout_164 (Dropout)       (None, 2, 2, 48)             0         ['conv2d_295[0][0]']
#
#  batch_normalization_288 (B  (None, 2, 2, 48)             192       ['dropout_164[0][0]']
#  atchNormalization)
#
#  activation_288 (Activation  (None, 2, 2, 48)             0         ['batch_normalization_288[0][0
#  )                                                                  ]']
#
#  conv2d_296 (Conv2D)         (None, 2, 2, 12)             5196      ['activation_288[0][0]']
#
#  dropout_165 (Dropout)       (None, 2, 2, 12)             0         ['conv2d_296[0][0]']
#
#  concatenate_165 (Concatena  (None, 2, 2, 336)            0         ['dropout_165[0][0]',
#  te)                                                                 'concatenate_164[0][0]']
#
#  batch_normalization_289 (B  (None, 2, 2, 336)            1344      ['concatenate_165[0][0]']
#  atchNormalization)
#
#  activation_289 (Activation  (None, 2, 2, 336)            0         ['batch_normalization_289[0][0
#  )                                                                  ]']
#
#  conv2d_297 (Conv2D)         (None, 2, 2, 48)             16176     ['activation_289[0][0]']
#
#  dropout_166 (Dropout)       (None, 2, 2, 48)             0         ['conv2d_297[0][0]']
#
#  batch_normalization_290 (B  (None, 2, 2, 48)             192       ['dropout_166[0][0]']
#  atchNormalization)
#
#  activation_290 (Activation  (None, 2, 2, 48)             0         ['batch_normalization_290[0][0
#  )                                                                  ]']
#
#  conv2d_298 (Conv2D)         (None, 2, 2, 12)             5196      ['activation_290[0][0]']
#
#  dropout_167 (Dropout)       (None, 2, 2, 12)             0         ['conv2d_298[0][0]']
#
#  concatenate_166 (Concatena  (None, 2, 2, 348)            0         ['dropout_167[0][0]',
#  te)                                                                 'concatenate_165[0][0]']
#
#  batch_normalization_291 (B  (None, 2, 2, 348)            1392      ['concatenate_166[0][0]']
#  atchNormalization)
#
#  activation_291 (Activation  (None, 2, 2, 348)            0         ['batch_normalization_291[0][0
#  )                                                                  ]']
#
#  conv2d_299 (Conv2D)         (None, 2, 2, 48)             16752     ['activation_291[0][0]']
#
#  dropout_168 (Dropout)       (None, 2, 2, 48)             0         ['conv2d_299[0][0]']
#
#  batch_normalization_292 (B  (None, 2, 2, 48)             192       ['dropout_168[0][0]']
#  atchNormalization)
#
#  activation_292 (Activation  (None, 2, 2, 48)             0         ['batch_normalization_292[0][0
#  )                                                                  ]']
#
#  conv2d_300 (Conv2D)         (None, 2, 2, 12)             5196      ['activation_292[0][0]']
#
#  dropout_169 (Dropout)       (None, 2, 2, 12)             0         ['conv2d_300[0][0]']
#
#  concatenate_167 (Concatena  (None, 2, 2, 360)            0         ['dropout_169[0][0]',
#  te)                                                                 'concatenate_166[0][0]']
#
#  batch_normalization_293 (B  (None, 2, 2, 360)            1440      ['concatenate_167[0][0]']
#  atchNormalization)
#
#  activation_293 (Activation  (None, 2, 2, 360)            0         ['batch_normalization_293[0][0
#  )                                                                  ]']
#
#  conv2d_301 (Conv2D)         (None, 2, 2, 48)             17328     ['activation_293[0][0]']
#
#  dropout_170 (Dropout)       (None, 2, 2, 48)             0         ['conv2d_301[0][0]']
#
#  batch_normalization_294 (B  (None, 2, 2, 48)             192       ['dropout_170[0][0]']
#  atchNormalization)
#
#  activation_294 (Activation  (None, 2, 2, 48)             0         ['batch_normalization_294[0][0
#  )                                                                  ]']
#
#  conv2d_302 (Conv2D)         (None, 2, 2, 12)             5196      ['activation_294[0][0]']
#
#  dropout_171 (Dropout)       (None, 2, 2, 12)             0         ['conv2d_302[0][0]']
#
#  concatenate_168 (Concatena  (None, 2, 2, 372)            0         ['dropout_171[0][0]',
#  te)                                                                 'concatenate_167[0][0]']
#
#  batch_normalization_295 (B  (None, 2, 2, 372)            1488      ['concatenate_168[0][0]']
#  atchNormalization)
#
#  activation_295 (Activation  (None, 2, 2, 372)            0         ['batch_normalization_295[0][0
#  )                                                                  ]']
#
#  conv2d_303 (Conv2D)         (None, 2, 2, 48)             17904     ['activation_295[0][0]']
#
#  dropout_172 (Dropout)       (None, 2, 2, 48)             0         ['conv2d_303[0][0]']
#
#  batch_normalization_296 (B  (None, 2, 2, 48)             192       ['dropout_172[0][0]']
#  atchNormalization)
#
#  activation_296 (Activation  (None, 2, 2, 48)             0         ['batch_normalization_296[0][0
#  )                                                                  ]']
#
#  conv2d_304 (Conv2D)         (None, 2, 2, 12)             5196      ['activation_296[0][0]']
#
#  dropout_173 (Dropout)       (None, 2, 2, 12)             0         ['conv2d_304[0][0]']
#
#  concatenate_169 (Concatena  (None, 2, 2, 384)            0         ['dropout_173[0][0]',
#  te)                                                                 'concatenate_168[0][0]']
#
#  batch_normalization_297 (B  (None, 2, 2, 384)            1536      ['concatenate_169[0][0]']
#  atchNormalization)
#
#  activation_297 (Activation  (None, 2, 2, 384)            0         ['batch_normalization_297[0][0
#  )                                                                  ]']
#
#  global_average_pooling2d_8  (None, 384)                  0         ['activation_297[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_9 (Dense)             (None, 10)                   3850      ['global_average_pooling2d_8[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 641698 (2.45 MB)
# Trainable params: 621658 (2.37 MB)
# Non-trainable params: 20040 (78.28 KB)
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
hist = model.fit(X_train, Y_train, epochs=2, batch_size=32, validation_split=0.1,
                 callbacks=[tf.keras.callbacks.EarlyStopping(patience=5)])
# Out:
# Epoch 1/2
# 1407/1407 [==============================] - 354s 222ms/step - loss: 1.6182 - accuracy: 0.4004 - val_loss: 1.6476 - val_accuracy: 0.4118
# Epoch 2/2
# 1407/1407 [==============================] - 298s 212ms/step - loss: 1.3042 - accuracy: 0.5306 - val_loss: 1.6030 - val_accuracy: 0.4748

# %%
# Model Evaluation
loss, accuracy = model.evaluate(X_test, Y_test, verbose=0)
print("Test Loss: ", loss)
print("Test Accuracy: ", accuracy)
# Out:
# Test Loss:  1.599199652671814
# Test Accuracy:  0.48159998655319214
